# %% [markdown]
# <a href="https://colab.research.google.com/github/2303A51256/Competitive-Programming/blob/main/Week_1_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
t = int(input().strip())

for i in range(t):
    n = int(input().strip())
    meetings = []

    for j in range(n):
        s, e = map(int, input().split())
        meetings.append((s, e))

    # Sort meetings by end time
    meetings.sort(key=lambda x: x[1])

    count = 1
    last_end = meetings[0][1]
    for i in range(1, n):
        if meetings[i][0] >= last_end:
            count += 1
            last_end = meetings[i][1]

    print(count)
# Out:
# 1
# 3
# 1 3
# 2 4
# 3 5
# 2
